# %%
# Import libaries
import pandas as pd
import numpy as np
import os

# %%
# Import file
path = r'/Users/brucehickling/Library/CloudStorage/Dropbox/Courses/CareerFoundry/Data Immersion/4_Python/02-2023_Instacart Basket Analysis'

# %%
df_ords_prods_customer = pd.read_pickle(os.path.join(path, '02 Data', 'Prepared Data', 'orders_products_customers.pkl'))

# %%
df_ords_prods_customer.head()
# Out:
#    product_id                product_name  aisle_id  department_id  prices  \
# 0           1  Chocolate Sandwich Cookies        61             19     5.8
# 1           1  Chocolate Sandwich Cookies        61             19     5.8
# 2         907        Premium Sliced Bacon       106             12    20.0
# 3         907        Premium Sliced Bacon       106             12    20.0
# 4        1000                    Apricots        18             10    12.9
#
#    order_id user_id  order_number  orders_day_of_week  order_hour_of_day  ...  \
# 0   3139998     138            28                   6                 11  ...
# 1   1977647     138            30                   6                 17  ...
# 2   3160996     138             1                   5                 13  ...
# 3   2254091     138            10                   5                 14  ...
# 4    505689     138             9                   6                 12  ...
#
# ...

# %%
# Create a crosstab between 'days_since_prior_order' and 'order_number' to confirm that all missing data in 'days_since_prior_order' are where 'order_number' = 1
crosstab = pd.crosstab(df_ords_prods_customer['days_since_prior_order'], df_ords_prods_customer['order_number'], dropna = False)

# %%
# Send to excel to view using clipboard
crosstab.to_clipboard()
