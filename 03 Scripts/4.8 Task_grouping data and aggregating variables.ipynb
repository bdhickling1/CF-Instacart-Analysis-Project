# %% [markdown]
# # 01. Task 4.8, Step 1

# %% [markdown]
# __Create a new notebook for this task. Be sure to import the relevant libraries, along with your ords_prods_merge dataframe, which should include your newly derived columns from the previous Exercise__

# %% [markdown]
# ## 1.1 Importing libraries

# %%
# Importing pandas, numpy, and os libraries
# Import libaries
import pandas as pd
import numpy as np
import os

# %% [markdown]
# ## 1.2 Importing data sets

# %%
# Import the orders_products_merged_derived.pkl file
path = r'/Users/brucehickling/Library/CloudStorage/Dropbox/Courses/CareerFoundry/Data Immersion/4_Python/02-2023_Instacart Basket Analysis'

# %%
df_ords_prods_merge = pd.read_pickle(os.path.join(path, '02 Data', 'Prepared Data', 'orders_products_merged_derived.pkl'))

# %%
# Check shape, dimensions, and column names
df_ords_prods_merge.head()
# Out:
#    product_id                product_name  aisle_id  department_id  prices  \
# 0           1  Chocolate Sandwich Cookies        61             19     5.8
# 1           1  Chocolate Sandwich Cookies        61             19     5.8
# 2           1  Chocolate Sandwich Cookies        61             19     5.8
# 3           1  Chocolate Sandwich Cookies        61             19     5.8
# 4           1  Chocolate Sandwich Cookies        61             19     5.8
#
#    order_id  user_id  order_number  orders_day_of_week  order_hour_of_day  \
# 0   3139998      138            28                   6                 11
# 1   1977647      138            30                   6                 17
# 2    389851      709             2                   0                 21
# 3    652770      764             1                   3                 13
# 4   1813452      764             3                   4                 17
#
# ...

# %%
df_ords_prods_merge.shape
# Out:
# (32404859, 17)

# %% [markdown]
# # 02. Task 4.8, Step 2

# %% [markdown]
# __In this Exercise, you learned how to find the aggregated mean of the “order_number” column grouped by “department_id” for a subset of your dataframe. Now, repeat this process for the entire dataframe__

# %%
# Using agg() group data by 'department_id' and aggregate the 'order_number' data to get the average of orders by department group
df_ords_prods_merge.groupby('department_id').agg({'order_number': ['mean']})
# Out:
#               order_number
#                       mean
# department_id
# 1                15.457838
# 2                17.277920
# 3                17.170395
# 4                17.811403
# 5                15.215751
# 6                16.439806
# 7                17.225802
# 8                15.340650
# 9                15.895474
# 10               20.197148
# 11               16.170638
# 12               15.887671
# 13               16.583536
# 14               16.773669
# 15               16.165037
# 16               17.665606
# 17               15.694469
# 18               19.310397
# 19               17.177343
# 20               16.473447
# 21               22.902379

# %%
# Aggregate without using agg() - obtain mean of 'order_number' using .mean() function
df_ords_prods_merge.groupby('department_id')['order_number'].mean()
# Out:
# department_id
# 1     15.457838
# 2     17.277920
# 3     17.170395
# 4     17.811403
# 5     15.215751
# 6     16.439806
# 7     17.225802
# 8     15.340650
# 9     15.895474
# 10    20.197148
# 11    16.170638
# 12    15.887671
# 13    16.583536
# 14    16.773669
# 15    16.165037
# 16    17.665606
# 17    15.694469
# 18    19.310397
# 19    17.177343
# 20    16.473447
# 21    22.902379
# Name: order_number, dtype: float64

# %% [markdown]
# # 03. Task 4.8, Step 3

# %% [markdown]
# __Analyze the result. How do the results for the entire dataframe differ from those of the subset? Include your comments in a markdown cell below the executed code__

# %% [markdown]
# __Response to Step 3: the results from the full dataframe differ slightly from those of the subset - some values are larger and some are smaller - but the subset only provides a sample of the full data. and so the results from the dataframe will be more accurate.__

# %% [markdown]
# # 04. Task 4.8, Step 4

# %% [markdown]
# __Follow the instructions in the Exercise for creating a loyalty flag for existing customers using the transform() and loc() functions__

# %% [markdown]
# ## 4.1 Use transform() to create a new column containing the maximum frequency of the 'order_number' column

# %%
df_ords_prods_merge['max_order'] = df_ords_prods_merge.groupby(['user_id'])['order_number'].transform(np.max)

# %%
# Verify the newly created column 'max_order'
df_ords_prods_merge.head(15)
# Out:
#     product_id                product_name  aisle_id  department_id  prices  \
# 0            1  Chocolate Sandwich Cookies        61             19     5.8
# 1            1  Chocolate Sandwich Cookies        61             19     5.8
# 2            1  Chocolate Sandwich Cookies        61             19     5.8
# 3            1  Chocolate Sandwich Cookies        61             19     5.8
# 4            1  Chocolate Sandwich Cookies        61             19     5.8
# 5            1  Chocolate Sandwich Cookies        61             19     5.8
# 6            1  Chocolate Sandwich Cookies        61             19     5.8
# 7            1  Chocolate Sandwich Cookies        61             19     5.8
# 8            1  Chocolate Sandwich Cookies        61             19     5.8
# 9            1  Chocolate Sandwich Cookies        61             19     5.8
# 10           1  Chocolate Sandwich Cookies        61             19     5.8
# ...

# %%
df_ords_prods_merge.shape
# Out:
# (32404859, 18)

# %%
# Creating the loyalty flags and deriving the new column 'max_order' with the loc() function
df_ords_prods_merge.loc[df_ords_prods_merge['max_order'] > 40, 'loyalty_flag'] = 'Loyal customer'

# %%
df_ords_prods_merge.loc[(df_ords_prods_merge['max_order'] <=40) & (df_ords_prods_merge['max_order'] > 10), 'loyalty_flag'] = 'Regular customer'

# %%
df_ords_prods_merge.loc[df_ords_prods_merge['max_order'] <= 10, 'loyalty_flag'] = 'New customer'

# %% [markdown]
# ## 4.2 Check and verify the new column by

# %%
# Print the frequency of the 'loyalty_flag' column
df_ords_prods_merge['loyalty_flag'].value_counts (dropna = False)
# Out:
# Regular customer    15876776
# Loyal customer      10284093
# New customer         6243990
# Name: loyalty_flag, dtype: int64

# %%
# Check the flag has been correctly applied
df_ords_prods_merge[['user_id', 'order_number', 'loyalty_flag']].head(30)
# Out:
#     user_id  order_number      loyalty_flag
# 0       138            28  Regular customer
# 1       138            30  Regular customer
# 2       709             2      New customer
# 3       764             1      New customer
# 4       764             3      New customer
# 5       777            16  Regular customer
# 6       825             3      New customer
# 7       910            12  Regular customer
# 8      1052            10  Regular customer
# 9      1052            15  Regular customer
# 10     1379             1      New customer
# 11     1480            36    Loyal customer
# 12     1480            38    Loyal customer
# 13     1480            39    Loyal customer
# 14     1494             6  Regular customer
# 15     1494             7  Regular customer
# 16     1494             9  Regular customer
# 17     1540             4  Regular customer
# 18     1540             5  Regular customer
# 19     1540             6  Regular customer
# ...

# %% [markdown]
# # 05. Task 4.8, Step 5

# %% [markdown]
# __The marketing team at Instacart wants to know whether there’s a difference between the spending habits of the three types of customers you identified. Use the loyalty flag you created and check the basic statistics of the product prices for each loyalty category (Loyal Customer, Regular Customer, and New Customer). What you’re trying to determine is whether the prices of products purchased by loyal customers differ from those purchased by regular or new customers.__

# %%
# Use agg() to derive mean, minimum, and maximum of values from the 'prices' column after grouping by 'loyalty_flag'
df_ords_prods_merge.groupby('loyalty_flag').agg({'prices': ['mean', 'min', 'max', 'sum']})
# Out:
#                      prices
#                        mean  min      max          sum
# loyalty_flag
# Loyal customer    10.386336  1.0  99999.0  106814042.2
# New customer      13.294670  1.0  99999.0   83011787.2
# Regular customer  12.495717  1.0  99999.0  198391693.2

# %% [markdown]
# __New customers spend more per order on average than loyal and regular customers, whereas loyal customers have the lowest average spend per order__

# %% [markdown]
# # 06. Task 4.8, Step 6

# %% [markdown]
# __The team now wants to target different types of spenders in their marketing campaigns. This can be achieved by looking at the prices of the items people are buying. Create a spending flag for each user based on the average price across all their orders using the following criteria:
# If the mean of the prices of products purchased by a user is lower than 10, then flag them as a “Low spender.”
# If the mean of the prices of products purchased by a user is higher than or equal to 10, then flag them as a “High spender.”__

# %%
# Use transform and mean function of NumPy to derive the average spend of each customer
df_ords_prods_merge['average_order'] = df_ords_prods_merge.groupby(['user_id'])['prices'].transform(np.mean)

# %%
# Check df and verify the new column 'average_order'
df_ords_prods_merge.head(15)
# Out:
#     product_id                product_name  aisle_id  department_id  prices  \
# 0            1  Chocolate Sandwich Cookies        61             19     5.8
# 1            1  Chocolate Sandwich Cookies        61             19     5.8
# 2            1  Chocolate Sandwich Cookies        61             19     5.8
# 3            1  Chocolate Sandwich Cookies        61             19     5.8
# 4            1  Chocolate Sandwich Cookies        61             19     5.8
# 5            1  Chocolate Sandwich Cookies        61             19     5.8
# 6            1  Chocolate Sandwich Cookies        61             19     5.8
# 7            1  Chocolate Sandwich Cookies        61             19     5.8
# 8            1  Chocolate Sandwich Cookies        61             19     5.8
# 9            1  Chocolate Sandwich Cookies        61             19     5.8
# 10           1  Chocolate Sandwich Cookies        61             19     5.8
# ...

# %%
df_ords_prods_merge.shape
# Out:
# (32404859, 20)

# %%
# Create the spending flags and deriving the new column 'spending_flag' with the loc() function
df_ords_prods_merge.loc[df_ords_prods_merge['average_order'] >= 10, 'spending_flag'] = 'High spender'

# %%
df_ords_prods_merge.loc[df_ords_prods_merge['average_order'] < 10, 'spending_flag'] = 'Low spender'

# %%
# Check values of new column 'spending_flag' as well as dimensions of the df
df_ords_prods_merge.head(15)
# Out:
#     product_id                product_name  aisle_id  department_id  prices  \
# 0            1  Chocolate Sandwich Cookies        61             19     5.8
# 1            1  Chocolate Sandwich Cookies        61             19     5.8
# 2            1  Chocolate Sandwich Cookies        61             19     5.8
# 3            1  Chocolate Sandwich Cookies        61             19     5.8
# 4            1  Chocolate Sandwich Cookies        61             19     5.8
# 5            1  Chocolate Sandwich Cookies        61             19     5.8
# 6            1  Chocolate Sandwich Cookies        61             19     5.8
# 7            1  Chocolate Sandwich Cookies        61             19     5.8
# 8            1  Chocolate Sandwich Cookies        61             19     5.8
# 9            1  Chocolate Sandwich Cookies        61             19     5.8
# 10           1  Chocolate Sandwich Cookies        61             19     5.8
# ...

# %%
df_ords_prods_merge.shape
# Out:
# (32404859, 21)

# %% [markdown]
# # 07. Task 4.8, Step 7

# %% [markdown]
# __In order to send relevant notifications to users within the app (for instance, asking users if they want to buy the same item again), the Instacart team wants you to determine frequent versus non-frequent customers. Create an order frequency flag that marks the regularity of a user’s ordering behavior according to the median in the “days_since_prior_order” column. The criteria for the flag should be as follows:
# If the median of “days_since_prior_order” is higher than 20, then the customer should be labeled a “Non-frequent customer.”
# If the median is higher than 10 and lower than or equal to 20, then the customer should be labeled a “Regular customer.”
# If the median is lower than or equal to 10, then the customer should be labeled a “Frequent customer.”__

# %% [markdown]
# ## 7.1 Create order frequency flag using the median of the 'days_since_prior_order' values

# %%
# Use transform and the median function of NumPy to derive the median days since last order for each customer to create a new column 'median_order_frequency'
df_ords_prods_merge['median_order_frequency'] = df_ords_prods_merge.groupby(['user_id'])['days_since_prior_order'].transform(np.median)

# %%
df_ords_prods_merge.head()
# Out:
#    product_id                product_name  aisle_id  department_id  prices  \
# 0           1  Chocolate Sandwich Cookies        61             19     5.8
# 1           1  Chocolate Sandwich Cookies        61             19     5.8
# 2           1  Chocolate Sandwich Cookies        61             19     5.8
# 3           1  Chocolate Sandwich Cookies        61             19     5.8
# 4           1  Chocolate Sandwich Cookies        61             19     5.8
#
#    order_id  user_id  order_number  orders_day_of_week  order_hour_of_day  \
# 0   3139998      138            28                   6                 11
# 1   1977647      138            30                   6                 17
# 2    389851      709             2                   0                 21
# 3    652770      764             1                   3                 13
# 4   1813452      764             3                   4                 17
#
#    ...  reordered    price_range_loc     busiest_day  busiest_days  \
# ...

# %% [markdown]
# ## 7.2 Create 'order_frequency' flag

# %%
# Use loc() of 'order_frequency' to create the flag
df_ords_prods_merge.loc[df_ords_prods_merge['median_order_frequency'] > 20, 'order_frequency'] = 'Not-frequent customer'

# %%
df_ords_prods_merge.loc[(df_ords_prods_merge['median_order_frequency'] <= 20) & (df_ords_prods_merge['median_order_frequency'] > 10), 'order_frequency'] = 'Regular customer'

# %%
df_ords_prods_merge.loc[df_ords_prods_merge['median_order_frequency'] <= 10, 'order_frequency'] = 'Frequent customer'

# %%
# Check the accuracy of the new column and dimensions of the new dataframe
df_ords_prods_merge.head()
# Out:
#    product_id                product_name  aisle_id  department_id  prices  \
# 0           1  Chocolate Sandwich Cookies        61             19     5.8
# 1           1  Chocolate Sandwich Cookies        61             19     5.8
# 2           1  Chocolate Sandwich Cookies        61             19     5.8
# 3           1  Chocolate Sandwich Cookies        61             19     5.8
# 4           1  Chocolate Sandwich Cookies        61             19     5.8
#
#    order_id  user_id  order_number  orders_day_of_week  order_hour_of_day  \
# 0   3139998      138            28                   6                 11
# 1   1977647      138            30                   6                 17
# 2    389851      709             2                   0                 21
# 3    652770      764             1                   3                 13
# 4   1813452      764             3                   4                 17
#
# ...

# %%
df_ords_prods_merge.shape
# Out:
# (32404859, 23)

# %% [markdown]
# # 08. Task 4.8, Step 9

# %% [markdown]
# __Export your dataframe as a pickle file and store it correctly in your “Prepared Data” folder.__

# %%
# Export the results as 'orders_products_merged_aggregated.pkl'

# %%
df_ords_prods_merge.to_pickle(os.path.join(path, '02 Data', 'Prepared Data', 'orders_products_merged_aggregated.pkl'))
